# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File to Write
city_data_to_write = "Weather_Database/WeatherPy_Database.csv"

# %% [markdown]
# ### 1.3 Create 2K Random Latitudes and Longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ### 1.4 Get the Nearest City for Each Lat/Lng Pair

# %%
# Import the citipy module
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %% [markdown]
# ### 1.5 Perform an API call with the OpenWeatherMap

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Cll.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#%%script false --no-raise-error

# **** TESING ****
# Once this cell works and the data has been created,
# turn it off by uncommenting the line above to reduce
# the calls to the API.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | kaitangata
# Processing Record 3 of Set 1 | kununurra
# Processing Record 4 of Set 1 | aleksandrov gay
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | maldonado
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | xinxiang
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | udachnyy
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | kysyl-syr
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | verkhoyansk
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 1 | marawi
# Processing Record 24 of Set 1 | peace river
# Processing Record 25 of Set 1 | rajur
# Processing Record 26 of Set 1 | alta gracia
# Processing Record 27 of Set 1 | taltal
# Processing Record 28 of Set 1 | ambilobe
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | chatellerault
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | sao filipe
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | labuhan
# Processing Record 40 of Set 1 | odweyne
# Processing Record 41 of Set 1 | hofn
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | chivay
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | muros
# Processing Record 50 of Set 1 | havre-saint-pierre
# Processing Record 1 of Set 2 | delano
# Processing Record 2 of Set 2 | galanta
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | palmer
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | soyo
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | clyde river
# Processing Record 15 of Set 2 | avera
# Processing Record 16 of Set 2 | xinzhou
# Processing Record 17 of Set 2 | dryden
# Processing Record 18 of Set 2 | toulepleu
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | mayari
# City not found. Skipping...
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | roald
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | mocuba
# Processing Record 29 of Set 2 | waipawa
# Processing Record 30 of Set 2 | bell ville
# Processing Record 31 of Set 2 | arandis
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | bonavista
# Processing Record 37 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 2 | prince rupert
# Processing Record 39 of Set 2 | caravelas
# Processing Record 40 of Set 2 | nome
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | sosnogorsk
# Processing Record 43 of Set 2 | balfour
# Processing Record 44 of Set 2 | upington
# Processing Record 45 of Set 2 | sistranda
# Processing Record 46 of Set 2 | kayerkan
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | darhan
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | vao
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | shingu
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | ponta delgada
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | colesberg
# Processing Record 9 of Set 3 | pandan
# Processing Record 10 of Set 3 | gazanjyk
# Processing Record 11 of Set 3 | atar
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 3 | santa pola
# Processing Record 15 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 3 | araouane
# Processing Record 20 of Set 3 | sisimiut
# Processing Record 21 of Set 3 | rongcheng
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | rosario oeste
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | genhe
# Processing Record 27 of Set 3 | gwanda
# Processing Record 28 of Set 3 | lensk
# Processing Record 29 of Set 3 | bridlington
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | port hawkesbury
# Processing Record 32 of Set 3 | kaeo
# Processing Record 33 of Set 3 | rovaniemi
# Processing Record 34 of Set 3 | omboue
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | la ronge
# Processing Record 38 of Set 3 | milton
# Processing Record 39 of Set 3 | flin flon
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 3 | dunedin
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | kangaatsiaq
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | xiaoweizhai
# Processing Record 46 of Set 3 | colares
# Processing Record 47 of Set 3 | banting
# Processing Record 48 of Set 3 | aswan
# Processing Record 49 of Set 3 | jalu
# Processing Record 50 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 1 of Set 4 | yumen
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | ossett
# Processing Record 7 of Set 4 | goure
# Processing Record 8 of Set 4 | batticaloa
# Processing Record 9 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 4 | auki
# Processing Record 11 of Set 4 | katubao
# Processing Record 12 of Set 4 | bilibino
# Processing Record 13 of Set 4 | yulara
# Processing Record 14 of Set 4 | jamestown
# Processing Record 15 of Set 4 | stepnyak
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | baykit
# Processing Record 18 of Set 4 | redlands
# Processing Record 19 of Set 4 | aromashevo
# Processing Record 20 of Set 4 | deputatskiy
# Processing Record 21 of Set 4 | eyl
# Processing Record 22 of Set 4 | hithadhoo
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | lorengau
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | jumla
# Processing Record 27 of Set 4 | huilong
# Processing Record 28 of Set 4 | denpasar
# Processing Record 29 of Set 4 | kinangan
# Processing Record 30 of Set 4 | san pedro
# Processing Record 31 of Set 4 | sterling heights
# Processing Record 32 of Set 4 | mumbwa
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | lasa
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | kapaa
# Processing Record 39 of Set 4 | bosaso
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | roma
# Processing Record 43 of Set 4 | kamyaran
# Processing Record 44 of Set 4 | tombouctou
# Processing Record 45 of Set 4 | new norfolk
# Processing Record 46 of Set 4 | nouadhibou
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | maarianhamina
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | ahuimanu
# Processing Record 1 of Set 5 | krasnoselkup
# Processing Record 2 of Set 5 | idrinskoye
# Processing Record 3 of Set 5 | nelson bay
# Processing Record 4 of Set 5 | bac can
# City not found. Skipping...
# Processing Record 5 of Set 5 | saint anthony
# Processing Record 6 of Set 5 | nipawin
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | dakar
# Processing Record 9 of Set 5 | malazgirt
# Processing Record 10 of Set 5 | popondetta
# Processing Record 11 of Set 5 | mayo
# Processing Record 12 of Set 5 | port-gentil
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | caconda
# Processing Record 17 of Set 5 | murmashi
# Processing Record 18 of Set 5 | zonguldak
# Processing Record 19 of Set 5 | pacific grove
# Processing Record 20 of Set 5 | qaqortoq
# Processing Record 21 of Set 5 | yarada
# Processing Record 22 of Set 5 | soloneshnoye
# Processing Record 23 of Set 5 | dalvik
# Processing Record 24 of Set 5 | high level
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | cape town
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | cabatuan
# Processing Record 29 of Set 5 | broome
# Processing Record 30 of Set 5 | zunyi
# Processing Record 31 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | kidal
# Processing Record 34 of Set 5 | sakakah
# Processing Record 35 of Set 5 | balkhash
# Processing Record 36 of Set 5 | mainaguri
# Processing Record 37 of Set 5 | san francisco
# Processing Record 38 of Set 5 | half moon bay
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | vestmannaeyjar
# Processing Record 41 of Set 5 | faya
# Processing Record 42 of Set 5 | maragogi
# Processing Record 43 of Set 5 | chongwe
# Processing Record 44 of Set 5 | dhidhdhoo
# Processing Record 45 of Set 5 | wattegama
# Processing Record 46 of Set 5 | ornskoldsvik
# Processing Record 47 of Set 5 | dwarka
# Processing Record 48 of Set 5 | la libertad
# Processing Record 49 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 5 | belomorsk
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | hokitika
# Processing Record 3 of Set 6 | namatanai
# Processing Record 4 of Set 6 | sitka
# Processing Record 5 of Set 6 | sambava
# Processing Record 6 of Set 6 | yerbogachen
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | neath
# Processing Record 9 of Set 6 | inirida
# Processing Record 10 of Set 6 | edgewater
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | pozo colorado
# Processing Record 13 of Set 6 | monopoli
# Processing Record 14 of Set 6 | bogale
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | makakilo city
# Processing Record 17 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | kyabram
# Processing Record 20 of Set 6 | egvekinot
# Processing Record 21 of Set 6 | kajaani
# Processing Record 22 of Set 6 | hinton
# Processing Record 23 of Set 6 | athens
# Processing Record 24 of Set 6 | saint-joseph
# Processing Record 25 of Set 6 | simpang
# Processing Record 26 of Set 6 | nahavand
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | east london
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | moyale
# Processing Record 32 of Set 6 | sandpoint
# Processing Record 33 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | tazovskiy
# Processing Record 35 of Set 6 | hovd
# Processing Record 36 of Set 6 | te anau
# Processing Record 37 of Set 6 | bonthe
# Processing Record 38 of Set 6 | aleysk
# Processing Record 39 of Set 6 | xinmin
# Processing Record 40 of Set 6 | bria
# Processing Record 41 of Set 6 | meulaboh
# Processing Record 42 of Set 6 | sao domingos
# Processing Record 43 of Set 6 | cimahi
# Processing Record 44 of Set 6 | tautira
# Processing Record 45 of Set 6 | ambulu
# Processing Record 46 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 6 | pitsunda
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | seoul
# Processing Record 50 of Set 6 | wasilla
# Processing Record 1 of Set 7 | makat
# Processing Record 2 of Set 7 | bintulu
# Processing Record 3 of Set 7 | tamala
# Processing Record 4 of Set 7 | gat
# Processing Record 5 of Set 7 | namtsy
# Processing Record 6 of Set 7 | hasanabad
# Processing Record 7 of Set 7 | plettenberg bay
# Processing Record 8 of Set 7 | persianovskiy
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | cap-aux-meules
# Processing Record 11 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 7 | hamilton
# Processing Record 13 of Set 7 | akureyri
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 7 | manokwari
# Processing Record 17 of Set 7 | mezhdurechenskiy
# Processing Record 18 of Set 7 | ekhabi
# Processing Record 19 of Set 7 | ormara
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | olafsvik
# Processing Record 22 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 7 | sainte-marie
# Processing Record 24 of Set 7 | zhigalovo
# Processing Record 25 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 7 | fiche
# Processing Record 27 of Set 7 | lavrentiya
# Processing Record 28 of Set 7 | wexford
# Processing Record 29 of Set 7 | praya
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | namangan
# Processing Record 32 of Set 7 | tondano
# Processing Record 33 of Set 7 | kazachinskoye
# Processing Record 34 of Set 7 | plavinas
# Processing Record 35 of Set 7 | hvalso
# City not found. Skipping...
# Processing Record 36 of Set 7 | prince albert
# Processing Record 37 of Set 7 | tura
# Processing Record 38 of Set 7 | caceres
# Processing Record 39 of Set 7 | usinsk
# Processing Record 40 of Set 7 | ruy barbosa
# Processing Record 41 of Set 7 | kenai
# Processing Record 42 of Set 7 | zanesville
# Processing Record 43 of Set 7 | dongsheng
# Processing Record 44 of Set 7 | tilichiki
# Processing Record 45 of Set 7 | nyurba
# Processing Record 46 of Set 7 | lompoc
# Processing Record 47 of Set 7 | englewood
# Processing Record 48 of Set 7 | sabha
# Processing Record 49 of Set 7 | northam
# Processing Record 50 of Set 7 | jinka
# Processing Record 1 of Set 8 | paraiso
# Processing Record 2 of Set 8 | panzhihua
# Processing Record 3 of Set 8 | ustyuzhna
# Processing Record 4 of Set 8 | gorom-gorom
# Processing Record 5 of Set 8 | juneau
# Processing Record 6 of Set 8 | kilingi-nomme
# Processing Record 7 of Set 8 | plouzane
# Processing Record 8 of Set 8 | ishigaki
# Processing Record 9 of Set 8 | liverpool
# Processing Record 10 of Set 8 | leningradskiy
# Processing Record 11 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 8 | tulsipur
# Processing Record 13 of Set 8 | klyuchi
# Processing Record 14 of Set 8 | husavik
# Processing Record 15 of Set 8 | katsuura
# Processing Record 16 of Set 8 | langenburg
# Processing Record 17 of Set 8 | naryan-mar
# Processing Record 18 of Set 8 | charters towers
# Processing Record 19 of Set 8 | brae
# Processing Record 20 of Set 8 | kondinskoye
# Processing Record 21 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 8 | luwuk
# Processing Record 23 of Set 8 | okha
# Processing Record 24 of Set 8 | tadepallegudem
# Processing Record 25 of Set 8 | aurillac
# Processing Record 26 of Set 8 | katobu
# Processing Record 27 of Set 8 | basoko
# Processing Record 28 of Set 8 | parana
# Processing Record 29 of Set 8 | dongning
# Processing Record 30 of Set 8 | belle fourche
# Processing Record 31 of Set 8 | bayir
# Processing Record 32 of Set 8 | poum
# Processing Record 33 of Set 8 | la palma
# Processing Record 34 of Set 8 | itoman
# Processing Record 35 of Set 8 | milkovo
# Processing Record 36 of Set 8 | bloomingdale
# Processing Record 37 of Set 8 | khandyga
# Processing Record 38 of Set 8 | fairbanks
# Processing Record 39 of Set 8 | lodingen
# Processing Record 40 of Set 8 | ayacucho
# Processing Record 41 of Set 8 | valparaiso
# Processing Record 42 of Set 8 | qui nhon
# Processing Record 43 of Set 8 | kashi
# Processing Record 44 of Set 8 | nichinan
# Processing Record 45 of Set 8 | mandalgovi
# Processing Record 46 of Set 8 | taraza
# Processing Record 47 of Set 8 | konevo
# Processing Record 48 of Set 8 | oktyabrskoye
# Processing Record 49 of Set 8 | nizhniy odes
# Processing Record 50 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | ergani
# Processing Record 3 of Set 9 | lardos
# Processing Record 4 of Set 9 | oussouye
# Processing Record 5 of Set 9 | shevchenko
# Processing Record 6 of Set 9 | seminole
# Processing Record 7 of Set 9 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 8 of Set 9 | lakefield
# Processing Record 9 of Set 9 | dawson
# Processing Record 10 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 11 of Set 9 | atlantic city
# Processing Record 12 of Set 9 | uige
# Processing Record 13 of Set 9 | lazaro cardenas
# Processing Record 14 of Set 9 | sept-iles
# Processing Record 15 of Set 9 | laguna
# Processing Record 16 of Set 9 | honiara
# Processing Record 17 of Set 9 | komsomolskiy
# Processing Record 18 of Set 9 | pitea
# Processing Record 19 of Set 9 | gondanglegi
# Processing Record 20 of Set 9 | dingle
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | ancud
# Processing Record 23 of Set 9 | oranjestad
# Processing Record 24 of Set 9 | kelo
# Processing Record 25 of Set 9 | narsaq
# Processing Record 26 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 27 of Set 9 | pishva
# Processing Record 28 of Set 9 | lobatse
# Processing Record 29 of Set 9 | kumluca
# Processing Record 30 of Set 9 | nicoya
# Processing Record 31 of Set 9 | shelburne
# Processing Record 32 of Set 9 | haines junction
# Processing Record 33 of Set 9 | gravelbourg
# Processing Record 34 of Set 9 | dali
# Processing Record 35 of Set 9 | port macquarie
# Processing Record 36 of Set 9 | isangel
# Processing Record 37 of Set 9 | opuwo
# Processing Record 38 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 9 | saint george
# Processing Record 40 of Set 9 | samarai
# Processing Record 41 of Set 9 | erzin
# Processing Record 42 of Set 9 | barabai
# Processing Record 43 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 9 | pasighat
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | evensk
# Processing Record 47 of Set 9 | amudat
# Processing Record 48 of Set 9 | anadyr
# Processing Record 49 of Set 9 | kasongo
# Processing Record 50 of Set 9 | banjar
# Processing Record 1 of Set 10 | balikpapan
# Processing Record 2 of Set 10 | abha
# Processing Record 3 of Set 10 | savinka
# Processing Record 4 of Set 10 | pyapon
# Processing Record 5 of Set 10 | valentin gomez farias
# Processing Record 6 of Set 10 | baherden
# Processing Record 7 of Set 10 | mae hong son
# Processing Record 8 of Set 10 | tahoua
# Processing Record 9 of Set 10 | kimbe
# Processing Record 10 of Set 10 | mackay
# Processing Record 11 of Set 10 | salta
# Processing Record 12 of Set 10 | grand gaube
# Processing Record 13 of Set 10 | juegang
# Processing Record 14 of Set 10 | secovce
# Processing Record 15 of Set 10 | penzance
# Processing Record 16 of Set 10 | rafai
# Processing Record 17 of Set 10 | santa lucia
# Processing Record 18 of Set 10 | obuasi
# Processing Record 19 of Set 10 | port blair
# Processing Record 20 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 21 of Set 10 | acapulco
# Processing Record 22 of Set 10 | lethem
# Processing Record 23 of Set 10 | martapura
# Processing Record 24 of Set 10 | channel-port aux basques
# Processing Record 25 of Set 10 | canon city
# Processing Record 26 of Set 10 | wanning
# Processing Record 27 of Set 10 | jasper
# Processing Record 28 of Set 10 | cherskiy
# Processing Record 29 of Set 10 | taywarah
# Processing Record 30 of Set 10 | kalianget
# Processing Record 31 of Set 10 | caledon
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | buala
# Processing Record 34 of Set 10 | neryungri
# Processing Record 35 of Set 10 | bowen
# Processing Record 36 of Set 10 | marianske lazne
# Processing Record 37 of Set 10 | morondava
# Processing Record 38 of Set 10 | nizwa
# Processing Record 39 of Set 10 | adrar
# Processing Record 40 of Set 10 | boueni
# Processing Record 41 of Set 10 | sucre
# Processing Record 42 of Set 10 | kodinsk
# Processing Record 43 of Set 10 | thiadiaye
# Processing Record 44 of Set 10 | ust-kulom
# Processing Record 45 of Set 10 | delmas
# Processing Record 46 of Set 10 | nemuro
# Processing Record 47 of Set 10 | moose factory
# Processing Record 48 of Set 10 | abu dhabi
# Processing Record 49 of Set 10 | cockburn town
# Processing Record 50 of Set 10 | nishihara
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | coahuayana
# Processing Record 3 of Set 11 | honningsvag
# Processing Record 4 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 11 | romuli
# Processing Record 6 of Set 11 | pavlogradka
# Processing Record 7 of Set 11 | lokachi
# Processing Record 8 of Set 11 | batouri
# Processing Record 9 of Set 11 | cape coral
# Processing Record 10 of Set 11 | coruripe
# Processing Record 11 of Set 11 | orzhytsya
# Processing Record 12 of Set 11 | aguimes
# Processing Record 13 of Set 11 | alexandria
# Processing Record 14 of Set 11 | feira de santana
# Processing Record 15 of Set 11 | leshukonskoye
# Processing Record 16 of Set 11 | isla mujeres
# Processing Record 17 of Set 11 | henties bay
# Processing Record 18 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 11 | puerto escondido
# Processing Record 20 of Set 11 | beihai
# Processing Record 21 of Set 11 | caibarien
# Processing Record 22 of Set 11 | saint-augustin
# Processing Record 23 of Set 11 | camenca
# Processing Record 24 of Set 11 | morros
# Processing Record 25 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | mizdah
# Processing Record 28 of Set 11 | mount gambier
# Processing Record 29 of Set 11 | mindif
# Processing Record 30 of Set 11 | kopayhorod
# Processing Record 31 of Set 11 | rawson
# Processing Record 32 of Set 11 | ketchikan
# Processing Record 33 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 34 of Set 11 | jepara
# Processing Record 35 of Set 11 | labrea
# Processing Record 36 of Set 11 | buri
# Processing Record 37 of Set 11 | mehamn
# Processing Record 38 of Set 11 | sagamihara
# Processing Record 39 of Set 11 | naze
# Processing Record 40 of Set 11 | abong mbang
# Processing Record 41 of Set 11 | pitimbu
# Processing Record 42 of Set 11 | stekolnyy
# City not found. Skipping...
# Processing Record 43 of Set 11 | vredendal
# Processing Record 44 of Set 11 | salihli
# Processing Record 45 of Set 11 | mbala
# Processing Record 46 of Set 11 | manali
# Processing Record 47 of Set 11 | marsh harbour
# Processing Record 48 of Set 11 | chandbali
# Processing Record 49 of Set 11 | mancio lima
# Processing Record 50 of Set 11 | sorland
# Processing Record 1 of Set 12 | omsukchan
# Processing Record 2 of Set 12 | nenjiang
# Processing Record 3 of Set 12 | namibe
# Processing Record 4 of Set 12 | loudeac
# Processing Record 5 of Set 12 | san pedro de macoris
# Processing Record 6 of Set 12 | great yarmouth
# Processing Record 7 of Set 12 | ostrovnoy
# Processing Record 8 of Set 12 | sinazongwe
# Processing Record 9 of Set 12 | giyon
# Processing Record 10 of Set 12 | springdale
# Processing Record 11 of Set 12 | hue
# Processing Record 12 of Set 12 | lata
# Processing Record 13 of Set 12 | pedernales
# Processing Record 14 of Set 12 | saint-francois
# Processing Record 15 of Set 12 | goundi
# Processing Record 16 of Set 12 | port pirie
# Processing Record 17 of Set 12 | itaituba
# Processing Record 18 of Set 12 | tengzhou
# Processing Record 19 of Set 12 | balykshi
# Processing Record 20 of Set 12 | revyakino
# Processing Record 21 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 12 | emirdag
# Processing Record 23 of Set 12 | kozhva
# Processing Record 24 of Set 12 | luang prabang
# Processing Record 25 of Set 12 | mumford
# Processing Record 26 of Set 12 | viet tri
# Processing Record 27 of Set 12 | mount isa
# Processing Record 28 of Set 12 | daru
# Processing Record 29 of Set 12 | shebunino
# Processing Record 30 of Set 12 | tazmalt
# Processing Record 31 of Set 12 | ossora
# Processing Record 32 of Set 12 | dickinson
# Processing Record 33 of Set 12 | vancouver
# Processing Record 34 of Set 12 | solnechnyy
# Processing Record 35 of Set 12 | tiznit
# Processing Record 36 of Set 12 | arlit
# Processing Record 37 of Set 12 | edea
# Processing Record 38 of Set 12 | sharan
# Processing Record 39 of Set 12 | irbit
# Processing Record 40 of Set 12 | ayan
# Processing Record 41 of Set 12 | bakchar
# Processing Record 42 of Set 12 | sinnamary
# Processing Record 43 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 12 | mogadishu
# Processing Record 45 of Set 12 | chicama
# Processing Record 46 of Set 12 | reconquista
# Processing Record 47 of Set 12 | antalaha
# Processing Record 48 of Set 12 | inuvik
# Processing Record 49 of Set 12 | codrington
# Processing Record 50 of Set 12 | tabuk
# Processing Record 1 of Set 13 | pincher creek
# Processing Record 2 of Set 13 | jiazi
# Processing Record 3 of Set 13 | gladstone
# Processing Record 4 of Set 13 | camana
# Processing Record 5 of Set 13 | perth
# Processing Record 6 of Set 13 | burnie
# Processing Record 7 of Set 13 | deer lake
# Processing Record 8 of Set 13 | barcelos
# Processing Record 9 of Set 13 | guasdualito
# Processing Record 10 of Set 13 | yinchuan
# Processing Record 11 of Set 13 | itacare
# Processing Record 12 of Set 13 | oranjemund
# Processing Record 13 of Set 13 | arvika
# Processing Record 14 of Set 13 | lewistown
# Processing Record 15 of Set 13 | elat
# Processing Record 16 of Set 13 | hambantota
# Processing Record 17 of Set 13 | sekoma
# Processing Record 18 of Set 13 | batagay-alyta
# Processing Record 19 of Set 13 | raudeberg
# Processing Record 20 of Set 13 | formiga
# Processing Record 21 of Set 13 | peleduy
# Processing Record 22 of Set 13 | buritis
# Processing Record 23 of Set 13 | mahibadhoo
# Processing Record 24 of Set 13 | port antonio
# Processing Record 25 of Set 13 | mattru
# Processing Record 26 of Set 13 | tongchuan
# Processing Record 27 of Set 13 | sangmelima
# Processing Record 28 of Set 13 | dauphin
# Processing Record 29 of Set 13 | hualmay
# Processing Record 30 of Set 13 | belaya gora
# Processing Record 31 of Set 13 | motygino
# Processing Record 32 of Set 13 | cayenne
# Processing Record 33 of Set 13 | albanel
# Processing Record 34 of Set 13 | perigueux
# Processing Record 35 of Set 13 | dubti
# Processing Record 36 of Set 13 | san jeronimo
# Processing Record 37 of Set 13 | zalantun
# Processing Record 38 of Set 13 | porto novo
# Processing Record 39 of Set 13 | svetlaya
# Processing Record 40 of Set 13 | dom pedrito
# Processing Record 41 of Set 13 | mecca
# Processing Record 42 of Set 13 | nueva guinea
# Processing Record 43 of Set 13 | mana
# Processing Record 44 of Set 13 | parabel
# Processing Record 45 of Set 13 | wakkanai
# Processing Record 46 of Set 13 | conde
# Processing Record 47 of Set 13 | pietarsaari
# Processing Record 48 of Set 13 | fort nelson
# Processing Record 49 of Set 13 | freetown
# Processing Record 50 of Set 13 | yar-sale
# Processing Record 1 of Set 14 | fortuna
# Processing Record 2 of Set 14 | alihe
# Processing Record 3 of Set 14 | tarakan
# Processing Record 4 of Set 14 | fallon
# Processing Record 5 of Set 14 | tateyama
# Processing Record 6 of Set 14 | bo
# City not found. Skipping...
# Processing Record 7 of Set 14 | xam nua
# Processing Record 8 of Set 14 | celestun
# Processing Record 9 of Set 14 | trofors
# Processing Record 10 of Set 14 | atambua
# Processing Record 11 of Set 14 | trelew
# Processing Record 12 of Set 14 | moree
# Processing Record 13 of Set 14 | po
# City not found. Skipping...
# Processing Record 14 of Set 14 | bodh gaya
# Processing Record 15 of Set 14 | paamiut
# Processing Record 16 of Set 14 | san borja
# Processing Record 17 of Set 14 | norrtalje
# Processing Record 18 of Set 14 | kurilsk
# Processing Record 19 of Set 14 | mbaiki
# Processing Record 20 of Set 14 | xichang
# Processing Record 21 of Set 14 | cap malheureux
# Processing Record 22 of Set 14 | bullhead city
# Processing Record 23 of Set 14 | gigmoto
# Processing Record 24 of Set 14 | manggar
# Processing Record 25 of Set 14 | tadine
# Processing Record 26 of Set 14 | bolobo
# Processing Record 27 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 14 | sayyan
# Processing Record 29 of Set 14 | leonidion
# City not found. Skipping...
# Processing Record 30 of Set 14 | a coruna
# Processing Record 31 of Set 14 | yeppoon
# Processing Record 32 of Set 14 | carauari
# Processing Record 33 of Set 14 | polewali
# Processing Record 34 of Set 14 | muroto
# Processing Record 35 of Set 14 | champerico
# Processing Record 36 of Set 14 | boende
# Processing Record 37 of Set 14 | vanavara
# Processing Record 38 of Set 14 | salalah
# Processing Record 39 of Set 14 | agirish
# Processing Record 40 of Set 14 | umm lajj
# Processing Record 41 of Set 14 | cam ranh
# Processing Record 42 of Set 14 | saint-pierre
# Processing Record 43 of Set 14 | mombetsu
# Processing Record 44 of Set 14 | melilla
# Processing Record 45 of Set 14 | gazli
# Processing Record 46 of Set 14 | antofagasta
# Processing Record 47 of Set 14 | puerto carreno
# Processing Record 48 of Set 14 | alofi
# Processing Record 49 of Set 14 | orange
# Processing Record 50 of Set 14 | inhambane
# Processing Record 1 of Set 15 | borba
# Processing Record 2 of Set 15 | barranca
# Processing Record 3 of Set 15 | alta floresta
# Processing Record 4 of Set 15 | tres arroyos
# Processing Record 5 of Set 15 | chino valley
# Processing Record 6 of Set 15 | mapastepec
# Processing Record 7 of Set 15 | merauke
# Processing Record 8 of Set 15 | ayorou
# Processing Record 9 of Set 15 | namwala
# Processing Record 10 of Set 15 | san andres
# Processing Record 11 of Set 15 | zelenets
# Processing Record 12 of Set 15 | waingapu
# Processing Record 13 of Set 15 | methoni
# Processing Record 14 of Set 15 | ciudad bolivar
# Processing Record 15 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 15 | flinders
# Processing Record 17 of Set 15 | ust-ilimsk
# Processing Record 18 of Set 15 | kandi
# Processing Record 19 of Set 15 | goose creek
# Processing Record 20 of Set 15 | vidalia
# Processing Record 21 of Set 15 | richmond
# Processing Record 22 of Set 15 | zambezi
# Processing Record 23 of Set 15 | nago
# Processing Record 24 of Set 15 | ejido
# Processing Record 25 of Set 15 | tezu
# Processing Record 26 of Set 15 | kurumkan
# Processing Record 27 of Set 15 | filadelfia
# Processing Record 28 of Set 15 | port hedland
# Processing Record 29 of Set 15 | normal
# Processing Record 30 of Set 15 | kiruna
# Processing Record 31 of Set 15 | kedrovyy
# Processing Record 32 of Set 15 | hendijan
# City not found. Skipping...
# Processing Record 33 of Set 15 | talavera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %% [markdown]
# ### 1.7 Add the Data to a New DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Nikolskoye      RU  59.7035   30.7861     48.87        77          98
# 1       Kaitangata      NZ -46.2817  169.8464     45.66        67          75
# 2        Kununurra      AU -15.7667  128.7333     96.78        23           1
# 3  Aleksandrov Gay      RU  50.1470   48.5704     56.79        39          43
# 4       Bredasdorp      ZA -34.5322   20.0403     45.21        85          27
# 5          Qaanaaq      GL  77.4840  -69.3632     39.06        81          98
# 6          Ushuaia      AR -54.8000  -68.3000     33.46        80         100
# 7        Maldonado      UY -34.6667  -54.9167     49.39        74           0
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     66.25        65          88
# 9            Vaini      TO -21.2000 -175.2000     77.16        88          75
#
#    Wind Speed Current Description
# 0        4.76     overcast clouds
# 1       12.46          light rain
# 2        9.22           clear sky
# 3        9.01    scattered clouds
# 4        6.91    scattered clouds
# 5        8.52     overcast clouds
# 6       14.97          light snow
# 7        5.75           clear sky
# 8       11.99     overcast clouds
# 9       10.36       broken clouds

# %%
# Output the DataFrame into the CSV file "WeatherPy_Database.csv"
city_data_df.to_csv(city_data_to_write)
