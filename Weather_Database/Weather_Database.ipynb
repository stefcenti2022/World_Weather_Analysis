# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File to Write
city_data_to_write = "WeatherPy_Database.csv"

# %% [markdown]
# ### 1.3 Create 2K Random Latitudes and Longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ### 1.4 Get the Nearest City for Each Lat/Lng Pair

# %%
# Import the citipy module
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %% [markdown]
# ### 1.5 Perform an API call with the OpenWeatherMap

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Cll.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# %%script false --no-raise-error

# **** TESING ****
# Once this cell works and the data has been created,
# turn it off by uncommenting the line above to reduce
# the calls to the API.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marsaxlokk
# Processing Record 2 of Set 1 | hervey bay
# Processing Record 3 of Set 1 | taoudenni
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | maurawan
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | mogok
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | prado
# Processing Record 12 of Set 1 | san quintin
# Processing Record 13 of Set 1 | thinadhoo
# Processing Record 14 of Set 1 | burica
# City not found. Skipping...
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | leh
# Processing Record 19 of Set 1 | pocos de caldas
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | yining
# Processing Record 23 of Set 1 | rocha
# Processing Record 24 of Set 1 | quixada
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | guozhen
# Processing Record 27 of Set 1 | khash
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | karaton
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | hvolsvollur
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | djambala
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | mizdah
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | pacific grove
# Processing Record 41 of Set 1 | leningradskiy
# Processing Record 42 of Set 1 | arona
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | coachella
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | alofi
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | oskemen
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | linhares
# Processing Record 5 of Set 2 | quelimane
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | esperance
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | akhmeta
# Processing Record 10 of Set 2 | port-gentil
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | riyadh
# Processing Record 13 of Set 2 | noumea
# Processing Record 14 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 2 | manacapuru
# Processing Record 16 of Set 2 | daxian
# City not found. Skipping...
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | tomohon
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | bilibino
# Processing Record 21 of Set 2 | berdigestyakh
# Processing Record 22 of Set 2 | san rafael
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | misratah
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | porto walter
# Processing Record 29 of Set 2 | worland
# Processing Record 30 of Set 2 | sholavandan
# City not found. Skipping...
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | kalat
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | alpena
# Processing Record 38 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | ghanzi
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | goderich
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | aykhal
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | port hardy
# Processing Record 48 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 2 | puerto leguizamo
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | sao gabriel da cachoeira
# Processing Record 2 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 3 | broome
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | staryy oskol
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | manakara
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | tancuayalab
# City not found. Skipping...
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | andes
# Processing Record 13 of Set 3 | makakilo city
# Processing Record 14 of Set 3 | thabazimbi
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | bubaque
# Processing Record 17 of Set 3 | brae
# Processing Record 18 of Set 3 | rikitea
# Processing Record 19 of Set 3 | tessalit
# Processing Record 20 of Set 3 | amapa
# Processing Record 21 of Set 3 | marawi
# Processing Record 22 of Set 3 | nouadhibou
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | elbasan
# Processing Record 25 of Set 3 | preston
# Processing Record 26 of Set 3 | brigham city
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | korla
# Processing Record 29 of Set 3 | ranong
# Processing Record 30 of Set 3 | mwingi
# Processing Record 31 of Set 3 | prachuap khiri khan
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | bad windsheim
# Processing Record 34 of Set 3 | baghdad
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | aranos
# Processing Record 37 of Set 3 | lokosovo
# Processing Record 38 of Set 3 | tilichiki
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | sokoni
# Processing Record 41 of Set 3 | tygda
# Processing Record 42 of Set 3 | anadyr
# Processing Record 43 of Set 3 | chernenko
# Processing Record 44 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | sorland
# Processing Record 1 of Set 4 | mana
# Processing Record 2 of Set 4 | berlevag
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | batagay
# Processing Record 6 of Set 4 | byron bay
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | semnan
# Processing Record 9 of Set 4 | sioux lookout
# Processing Record 10 of Set 4 | peremyshl
# Processing Record 11 of Set 4 | alihe
# Processing Record 12 of Set 4 | palmer
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | port-cartier
# Processing Record 16 of Set 4 | bucerias
# Processing Record 17 of Set 4 | slave lake
# Processing Record 18 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | jaszapati
# Processing Record 21 of Set 4 | rawson
# Processing Record 22 of Set 4 | tarauaca
# Processing Record 23 of Set 4 | lieksa
# Processing Record 24 of Set 4 | cartagena
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | puerto baquerizo moreno
# Processing Record 27 of Set 4 | butaritari
# Processing Record 28 of Set 4 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | matara
# Processing Record 31 of Set 4 | hurricane
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | wagga wagga
# Processing Record 34 of Set 4 | pinhao
# Processing Record 35 of Set 4 | atuona
# Processing Record 36 of Set 4 | badami
# Processing Record 37 of Set 4 | broken hill
# Processing Record 38 of Set 4 | penzance
# Processing Record 39 of Set 4 | nome
# Processing Record 40 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 4 | jalu
# Processing Record 42 of Set 4 | huarmey
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | road town
# Processing Record 45 of Set 4 | san-pedro
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | taywarah
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | tukrah
# Processing Record 1 of Set 5 | kantang
# Processing Record 2 of Set 5 | taksimo
# Processing Record 3 of Set 5 | cheyenne
# Processing Record 4 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 5 | vale da amoreira
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | bredasdorp
# Processing Record 8 of Set 5 | tefe
# Processing Record 9 of Set 5 | touros
# Processing Record 10 of Set 5 | hay river
# Processing Record 11 of Set 5 | itapeva
# Processing Record 12 of Set 5 | hasaki
# Processing Record 13 of Set 5 | maniitsoq
# Processing Record 14 of Set 5 | dhandhuka
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | puri
# Processing Record 18 of Set 5 | santa rosa
# Processing Record 19 of Set 5 | wanxian
# Processing Record 20 of Set 5 | merrill
# Processing Record 21 of Set 5 | qasigiannguit
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | prainha
# Processing Record 24 of Set 5 | miraflores
# Processing Record 25 of Set 5 | saldanha
# Processing Record 26 of Set 5 | praia
# Processing Record 27 of Set 5 | tabuk
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | shar
# Processing Record 30 of Set 5 | suntar
# Processing Record 31 of Set 5 | carlet
# Processing Record 32 of Set 5 | kushmurun
# Processing Record 33 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 5 | lanja
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | sampit
# Processing Record 37 of Set 5 | cayenne
# Processing Record 38 of Set 5 | tabas
# Processing Record 39 of Set 5 | khani
# Processing Record 40 of Set 5 | payo
# Processing Record 41 of Set 5 | edd
# Processing Record 42 of Set 5 | aksu
# Processing Record 43 of Set 5 | panacan
# Processing Record 44 of Set 5 | dodge city
# Processing Record 45 of Set 5 | hami
# Processing Record 46 of Set 5 | ugoofaaru
# Processing Record 47 of Set 5 | port alfred
# Processing Record 48 of Set 5 | balkhash
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 50 of Set 5 | alugan
# Processing Record 1 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 6 | sao domingos
# Processing Record 3 of Set 6 | port shepstone
# Processing Record 4 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 6 | mount pleasant
# Processing Record 6 of Set 6 | high level
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 6 | sebrovo
# Processing Record 10 of Set 6 | cape coast
# Processing Record 11 of Set 6 | bonthe
# Processing Record 12 of Set 6 | mokhotlong
# Processing Record 13 of Set 6 | mahalingpur
# Processing Record 14 of Set 6 | rock springs
# Processing Record 15 of Set 6 | dir
# Processing Record 16 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | tsiroanomandidy
# Processing Record 19 of Set 6 | turochak
# Processing Record 20 of Set 6 | bereznik
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | meulaboh
# Processing Record 24 of Set 6 | faya
# Processing Record 25 of Set 6 | bushenyi
# Processing Record 26 of Set 6 | mananjary
# Processing Record 27 of Set 6 | dicabisagan
# Processing Record 28 of Set 6 | bethel
# Processing Record 29 of Set 6 | ellisras
# Processing Record 30 of Set 6 | achiotal
# City not found. Skipping...
# Processing Record 31 of Set 6 | san jeronimo
# Processing Record 32 of Set 6 | imeni babushkina
# Processing Record 33 of Set 6 | gardelegen
# Processing Record 34 of Set 6 | kaitangata
# Processing Record 35 of Set 6 | juba
# Processing Record 36 of Set 6 | narsaq
# Processing Record 37 of Set 6 | gondar
# Processing Record 38 of Set 6 | tevaitoa
# Processing Record 39 of Set 6 | wilmslow
# Processing Record 40 of Set 6 | vila velha
# Processing Record 41 of Set 6 | platanos
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | sangar
# Processing Record 44 of Set 6 | bowmore
# Processing Record 45 of Set 6 | chingirlau
# Processing Record 46 of Set 6 | gazli
# Processing Record 47 of Set 6 | itarema
# Processing Record 48 of Set 6 | le vauclin
# Processing Record 49 of Set 6 | sayula
# Processing Record 50 of Set 6 | novyy urengoy
# Processing Record 1 of Set 7 | maragogi
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | atar
# Processing Record 4 of Set 7 | mayo
# Processing Record 5 of Set 7 | litovko
# Processing Record 6 of Set 7 | oblivskaya
# Processing Record 7 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 7 | rio gallegos
# Processing Record 9 of Set 7 | tiksi
# Processing Record 10 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 7 | novokizhinginsk
# Processing Record 12 of Set 7 | hilo
# Processing Record 13 of Set 7 | plouzane
# Processing Record 14 of Set 7 | yulara
# Processing Record 15 of Set 7 | hun
# Processing Record 16 of Set 7 | juazeiro
# Processing Record 17 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 7 | bathsheba
# Processing Record 19 of Set 7 | araouane
# Processing Record 20 of Set 7 | batagay-alyta
# Processing Record 21 of Set 7 | diepholz
# Processing Record 22 of Set 7 | salalah
# Processing Record 23 of Set 7 | kamenka
# Processing Record 24 of Set 7 | baruun-urt
# Processing Record 25 of Set 7 | arraial do cabo
# Processing Record 26 of Set 7 | juneau
# Processing Record 27 of Set 7 | ahipara
# Processing Record 28 of Set 7 | fairbanks
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | eenhana
# Processing Record 31 of Set 7 | anloga
# Processing Record 32 of Set 7 | maxixe
# Processing Record 33 of Set 7 | varhaug
# Processing Record 34 of Set 7 | roma
# Processing Record 35 of Set 7 | portobelo
# Processing Record 36 of Set 7 | te anau
# Processing Record 37 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 7 | egvekinot
# Processing Record 39 of Set 7 | abnub
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | mange
# Processing Record 42 of Set 7 | constitucion
# Processing Record 43 of Set 7 | tuatapere
# Processing Record 44 of Set 7 | mitsamiouli
# Processing Record 45 of Set 7 | manta
# Processing Record 46 of Set 7 | obihiro
# Processing Record 47 of Set 7 | narasaraopet
# Processing Record 48 of Set 7 | yeniseysk
# Processing Record 49 of Set 7 | sterling
# Processing Record 50 of Set 7 | krasnopavlivka
# Processing Record 1 of Set 8 | saint anthony
# Processing Record 2 of Set 8 | iquique
# Processing Record 3 of Set 8 | crestview
# Processing Record 4 of Set 8 | istok
# Processing Record 5 of Set 8 | upernavik
# Processing Record 6 of Set 8 | olafsvik
# Processing Record 7 of Set 8 | french harbor
# Processing Record 8 of Set 8 | harer
# Processing Record 9 of Set 8 | ambilobe
# Processing Record 10 of Set 8 | alice springs
# Processing Record 11 of Set 8 | veere
# Processing Record 12 of Set 8 | tezu
# Processing Record 13 of Set 8 | dingle
# Processing Record 14 of Set 8 | tagusao
# Processing Record 15 of Set 8 | faanui
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | talara
# Processing Record 18 of Set 8 | keningau
# Processing Record 19 of Set 8 | serenje
# Processing Record 20 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 8 | rafaela
# Processing Record 22 of Set 8 | kashi
# Processing Record 23 of Set 8 | naumburg
# Processing Record 24 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 8 | knysna
# Processing Record 26 of Set 8 | nuuk
# Processing Record 27 of Set 8 | lima
# Processing Record 28 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 8 | tyup
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | nelson bay
# Processing Record 32 of Set 8 | zhangye
# Processing Record 33 of Set 8 | xuanzhou
# Processing Record 34 of Set 8 | ginda
# Processing Record 35 of Set 8 | bafra
# Processing Record 36 of Set 8 | chenghai
# Processing Record 37 of Set 8 | puerto vallarta
# Processing Record 38 of Set 8 | pasco
# Processing Record 39 of Set 8 | kloulklubed
# Processing Record 40 of Set 8 | coswig
# Processing Record 41 of Set 8 | maldonado
# Processing Record 42 of Set 8 | manggar
# Processing Record 43 of Set 8 | poronaysk
# Processing Record 44 of Set 8 | seda
# Processing Record 45 of Set 8 | torbay
# Processing Record 46 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 47 of Set 8 | mindelo
# Processing Record 48 of Set 8 | turbat
# Processing Record 49 of Set 8 | hobyo
# Processing Record 50 of Set 8 | ivdel
# Processing Record 1 of Set 9 | belyy yar
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | fleetwood
# Processing Record 4 of Set 9 | kungurtug
# Processing Record 5 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 9 | pangai
# Processing Record 7 of Set 9 | ancud
# Processing Record 8 of Set 9 | abu zabad
# Processing Record 9 of Set 9 | chachoengsao
# Processing Record 10 of Set 9 | dalbeattie
# Processing Record 11 of Set 9 | nang rong
# Processing Record 12 of Set 9 | gat
# Processing Record 13 of Set 9 | mapiri
# Processing Record 14 of Set 9 | tuzla
# Processing Record 15 of Set 9 | cabra
# Processing Record 16 of Set 9 | vila
# Processing Record 17 of Set 9 | agnibilekrou
# Processing Record 18 of Set 9 | westport
# Processing Record 19 of Set 9 | yamada
# Processing Record 20 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 21 of Set 9 | kismayo
# Processing Record 22 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 9 | puro
# Processing Record 24 of Set 9 | cabo san lucas
# Processing Record 25 of Set 9 | chilca
# Processing Record 26 of Set 9 | yinchuan
# Processing Record 27 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | port hedland
# Processing Record 29 of Set 9 | alyangula
# Processing Record 30 of Set 9 | morehead
# Processing Record 31 of Set 9 | sorong
# Processing Record 32 of Set 9 | coihaique
# Processing Record 33 of Set 9 | hovd
# Processing Record 34 of Set 9 | wheat ridge
# Processing Record 35 of Set 9 | mujiayingzi
# Processing Record 36 of Set 9 | poum
# Processing Record 37 of Set 9 | ak-dovurak
# Processing Record 38 of Set 9 | roald
# Processing Record 39 of Set 9 | talcahuano
# Processing Record 40 of Set 9 | aguimes
# Processing Record 41 of Set 9 | dengzhou
# Processing Record 42 of Set 9 | erenhot
# Processing Record 43 of Set 9 | okhotsk
# Processing Record 44 of Set 9 | khandyga
# Processing Record 45 of Set 9 | chapais
# Processing Record 46 of Set 9 | chitral
# Processing Record 47 of Set 9 | beckley
# Processing Record 48 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 49 of Set 9 | chulman
# Processing Record 50 of Set 9 | abilene
# Processing Record 1 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 2 of Set 10 | vila franca do campo
# Processing Record 3 of Set 10 | hambantota
# Processing Record 4 of Set 10 | fuerte
# Processing Record 5 of Set 10 | namanga
# Processing Record 6 of Set 10 | quartucciu
# Processing Record 7 of Set 10 | mattru
# Processing Record 8 of Set 10 | abu dhabi
# Processing Record 9 of Set 10 | pervoye maya
# Processing Record 10 of Set 10 | dubrovytsya
# Processing Record 11 of Set 10 | iranshahr
# Processing Record 12 of Set 10 | choma
# Processing Record 13 of Set 10 | tiquisio
# Processing Record 14 of Set 10 | pinawa
# Processing Record 15 of Set 10 | marienburg
# Processing Record 16 of Set 10 | mawlaik
# Processing Record 17 of Set 10 | jardim
# Processing Record 18 of Set 10 | huoqiu
# Processing Record 19 of Set 10 | lumeje
# Processing Record 20 of Set 10 | dubbo
# Processing Record 21 of Set 10 | porto santo
# Processing Record 22 of Set 10 | sompeta
# Processing Record 23 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | auki
# Processing Record 25 of Set 10 | pasaco
# Processing Record 26 of Set 10 | marsabit
# Processing Record 27 of Set 10 | nuevo casas grandes
# Processing Record 28 of Set 10 | dhidhdhoo
# Processing Record 29 of Set 10 | steubenville
# Processing Record 30 of Set 10 | peking
# Processing Record 31 of Set 10 | skibbereen
# Processing Record 32 of Set 10 | kalemie
# Processing Record 33 of Set 10 | emerald
# Processing Record 34 of Set 10 | grand gaube
# Processing Record 35 of Set 10 | zolochiv
# Processing Record 36 of Set 10 | oromocto
# Processing Record 37 of Set 10 | cotonou
# Processing Record 38 of Set 10 | coos bay
# Processing Record 39 of Set 10 | ayan
# Processing Record 40 of Set 10 | yaan
# Processing Record 41 of Set 10 | hualmay
# Processing Record 42 of Set 10 | puerto del rosario
# Processing Record 43 of Set 10 | beloha
# Processing Record 44 of Set 10 | nisia floresta
# Processing Record 45 of Set 10 | isla vista
# Processing Record 46 of Set 10 | waingapu
# Processing Record 47 of Set 10 | samarai
# Processing Record 48 of Set 10 | geraldton
# Processing Record 49 of Set 10 | beverly hills
# Processing Record 50 of Set 10 | islamabad
# Processing Record 1 of Set 11 | namatanai
# Processing Record 2 of Set 11 | almaty
# Processing Record 3 of Set 11 | newry
# Processing Record 4 of Set 11 | gander
# Processing Record 5 of Set 11 | champerico
# Processing Record 6 of Set 11 | toledo
# Processing Record 7 of Set 11 | grindavik
# Processing Record 8 of Set 11 | zaruma
# Processing Record 9 of Set 11 | hamilton
# Processing Record 10 of Set 11 | seoul
# Processing Record 11 of Set 11 | havre-saint-pierre
# Processing Record 12 of Set 11 | tocopilla
# Processing Record 13 of Set 11 | baykit
# Processing Record 14 of Set 11 | beba
# Processing Record 15 of Set 11 | san juan
# Processing Record 16 of Set 11 | farmington
# Processing Record 17 of Set 11 | nakamura
# Processing Record 18 of Set 11 | ust-ilimsk
# Processing Record 19 of Set 11 | boundiali
# Processing Record 20 of Set 11 | kutoarjo
# Processing Record 21 of Set 11 | aland
# Processing Record 22 of Set 11 | sarankhola
# Processing Record 23 of Set 11 | camopi
# Processing Record 24 of Set 11 | cap-aux-meules
# Processing Record 25 of Set 11 | zonguldak
# Processing Record 26 of Set 11 | coari
# Processing Record 27 of Set 11 | papara
# Processing Record 28 of Set 11 | pochutla
# Processing Record 29 of Set 11 | san patricio
# Processing Record 30 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 11 | sydney
# Processing Record 32 of Set 11 | marfino
# Processing Record 33 of Set 11 | abbeville
# Processing Record 34 of Set 11 | mwense
# Processing Record 35 of Set 11 | sigiriya
# Processing Record 36 of Set 11 | ostrovnoy
# Processing Record 37 of Set 11 | luanda
# Processing Record 38 of Set 11 | gbadolite
# Processing Record 39 of Set 11 | susangerd
# Processing Record 40 of Set 11 | vanavara
# Processing Record 41 of Set 11 | teya
# Processing Record 42 of Set 11 | nantucket
# Processing Record 43 of Set 11 | snezhnogorsk
# Processing Record 44 of Set 11 | namibe
# Processing Record 45 of Set 11 | birjand
# Processing Record 46 of Set 11 | laguna
# Processing Record 47 of Set 11 | tura
# Processing Record 48 of Set 11 | khuzhir
# Processing Record 49 of Set 11 | nur
# Processing Record 50 of Set 11 | quatre cocos
# Processing Record 1 of Set 12 | sonoita
# Processing Record 2 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 12 | sitka
# Processing Record 5 of Set 12 | henties bay
# Processing Record 6 of Set 12 | usakos
# Processing Record 7 of Set 12 | guerrero negro
# Processing Record 8 of Set 12 | cibeureum
# Processing Record 9 of Set 12 | brownsville
# Processing Record 10 of Set 12 | santa cruz cabralia
# Processing Record 11 of Set 12 | emba
# Processing Record 12 of Set 12 | banjar
# Processing Record 13 of Set 12 | tateyama
# Processing Record 14 of Set 12 | cap malheureux
# Processing Record 15 of Set 12 | altay
# Processing Record 16 of Set 12 | jurado
# Processing Record 17 of Set 12 | paamiut
# Processing Record 18 of Set 12 | arlit
# Processing Record 19 of Set 12 | toamasina
# Processing Record 20 of Set 12 | cockburn town
# Processing Record 21 of Set 12 | coahuayana
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | mirnyy
# Processing Record 24 of Set 12 | sola
# Processing Record 25 of Set 12 | bure
# Processing Record 26 of Set 12 | baft
# Processing Record 27 of Set 12 | sirajganj
# Processing Record 28 of Set 12 | we
# City not found. Skipping...
# Processing Record 29 of Set 12 | luganville
# Processing Record 30 of Set 12 | isangel
# Processing Record 31 of Set 12 | sistranda
# Processing Record 32 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 12 | barsovo
# Processing Record 34 of Set 12 | nouakchott
# Processing Record 35 of Set 12 | kutum
# Processing Record 36 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 37 of Set 12 | kingisepp
# Processing Record 38 of Set 12 | la sarre
# Processing Record 39 of Set 12 | san marcos
# Processing Record 40 of Set 12 | manicore
# Processing Record 41 of Set 12 | bom jardim
# Processing Record 42 of Set 12 | markova
# Processing Record 43 of Set 12 | tokat
# Processing Record 44 of Set 12 | longyearbyen
# Processing Record 45 of Set 12 | cumana
# Processing Record 46 of Set 12 | kulu
# Processing Record 47 of Set 12 | pho chai
# Processing Record 48 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 49 of Set 12 | yashan
# Processing Record 50 of Set 12 | sulangan
# Processing Record 1 of Set 13 | novyy chirkey
# Processing Record 2 of Set 13 | mahibadhoo
# Processing Record 3 of Set 13 | swan river
# Processing Record 4 of Set 13 | shibetsu
# Processing Record 5 of Set 13 | beitbridge
# Processing Record 6 of Set 13 | devils lake
# Processing Record 7 of Set 13 | solvychegodsk
# Processing Record 8 of Set 13 | mukhen
# Processing Record 9 of Set 13 | malanje
# Processing Record 10 of Set 13 | clarksville
# Processing Record 11 of Set 13 | clarksburg
# Processing Record 12 of Set 13 | robertsport
# Processing Record 13 of Set 13 | muli
# Processing Record 14 of Set 13 | mercedes
# Processing Record 15 of Set 13 | diapaga
# Processing Record 16 of Set 13 | richards bay
# Processing Record 17 of Set 13 | jennings
# Processing Record 18 of Set 13 | ahuimanu
# Processing Record 19 of Set 13 | terra santa
# Processing Record 20 of Set 13 | kodiak
# Processing Record 21 of Set 13 | bonavista
# Processing Record 22 of Set 13 | sarai naurang
# Processing Record 23 of Set 13 | port augusta
# Processing Record 24 of Set 13 | lasa
# Processing Record 25 of Set 13 | khowai
# Processing Record 26 of Set 13 | igbo ora
# Processing Record 27 of Set 13 | kaniama
# Processing Record 28 of Set 13 | buritis
# Processing Record 29 of Set 13 | sagua la grande
# Processing Record 30 of Set 13 | songjianghe
# Processing Record 31 of Set 13 | saint-pierre
# Processing Record 32 of Set 13 | itaueira
# Processing Record 33 of Set 13 | ariquemes
# Processing Record 34 of Set 13 | hofn
# Processing Record 35 of Set 13 | nusaybin
# Processing Record 36 of Set 13 | ayagoz
# Processing Record 37 of Set 13 | cam ranh
# Processing Record 38 of Set 13 | manono
# Processing Record 39 of Set 13 | vinh
# Processing Record 40 of Set 13 | sao filipe
# Processing Record 41 of Set 13 | vanimo
# Processing Record 42 of Set 13 | sur
# Processing Record 43 of Set 13 | libreville
# Processing Record 44 of Set 13 | tazovskiy
# Processing Record 45 of Set 13 | farafangana
# Processing Record 46 of Set 13 | itaituba
# Processing Record 47 of Set 13 | uglegorsk
# Processing Record 48 of Set 13 | lazaro cardenas
# Processing Record 49 of Set 13 | makat
# Processing Record 50 of Set 13 | gualaquiza
# Processing Record 1 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 2 of Set 14 | beira
# Processing Record 3 of Set 14 | elliot
# Processing Record 4 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 5 of Set 14 | port keats
# Processing Record 6 of Set 14 | srednekolymsk
# Processing Record 7 of Set 14 | tecoanapa
# Processing Record 8 of Set 14 | mount gambier
# Processing Record 9 of Set 14 | les escoumins
# Processing Record 10 of Set 14 | san carlos de bariloche
# Processing Record 11 of Set 14 | yecla
# Processing Record 12 of Set 14 | tautira
# Processing Record 13 of Set 14 | tsukumi
# Processing Record 14 of Set 14 | sept-iles
# Processing Record 15 of Set 14 | kazerun
# Processing Record 16 of Set 14 | champawat
# Processing Record 17 of Set 14 | sisimiut
# Processing Record 18 of Set 14 | varna
# Processing Record 19 of Set 14 | ketchikan
# Processing Record 20 of Set 14 | boa vista
# Processing Record 21 of Set 14 | jamui
# Processing Record 22 of Set 14 | jumla
# Processing Record 23 of Set 14 | christchurch
# Processing Record 24 of Set 14 | joshimath
# Processing Record 25 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 14 | lavrentiya
# Processing Record 27 of Set 14 | lazurne
# Processing Record 28 of Set 14 | beringovskiy
# Processing Record 29 of Set 14 | zhaocheng
# City not found. Skipping...
# Processing Record 30 of Set 14 | ulaanbaatar
# Processing Record 31 of Set 14 | demba
# Processing Record 32 of Set 14 | marathon
# Processing Record 33 of Set 14 | gorom-gorom
# Processing Record 34 of Set 14 | avallon
# Processing Record 35 of Set 14 | kalmunai
# Processing Record 36 of Set 14 | adre
# Processing Record 37 of Set 14 | york
# Processing Record 38 of Set 14 | deputatskiy
# Processing Record 39 of Set 14 | ambanja
# Processing Record 40 of Set 14 | kibala
# Processing Record 41 of Set 14 | san andres
# Processing Record 42 of Set 14 | kurilsk
# Processing Record 43 of Set 14 | diego de almagro
# Processing Record 44 of Set 14 | araceli
# Processing Record 45 of Set 14 | imeni poliny osipenko
# Processing Record 46 of Set 14 | wanning
# Processing Record 47 of Set 14 | redmond
# Processing Record 48 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 49 of Set 14 | nerang
# Processing Record 50 of Set 14 | teguise
# Processing Record 1 of Set 15 | rincon
# Processing Record 2 of Set 15 | vilhena
# Processing Record 3 of Set 15 | villamontes
# Processing Record 4 of Set 15 | gizycko
# Processing Record 5 of Set 15 | tual
# Processing Record 6 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 15 | zhigansk
# Processing Record 8 of Set 15 | idlib
# Processing Record 9 of Set 15 | newton
# Processing Record 10 of Set 15 | barhi
# Processing Record 11 of Set 15 | fort nelson
# Processing Record 12 of Set 15 | praia da vitoria
# Processing Record 13 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 15 | surt
# Processing Record 15 of Set 15 | oxford
# Processing Record 16 of Set 15 | santa cruz
# Processing Record 17 of Set 15 | kayankulam
# Processing Record 18 of Set 15 | pilar
# Processing Record 19 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 15 | port said
# Processing Record 21 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 15 | mumbwa
# Processing Record 23 of Set 15 | albion
# Processing Record 24 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 15 | bismarck
# Processing Record 26 of Set 15 | makrana
# Processing Record 27 of Set 15 | vrangel
# Processing Record 28 of Set 15 | odweyne
# Processing Record 29 of Set 15 | pueblo
# Processing Record 30 of Set 15 | south yuba city
# Processing Record 31 of Set 15 | pecos
# Processing Record 32 of Set 15 | namwala
# Processing Record 33 of Set 15 | yerbogachen
# Processing Record 34 of Set 15 | la uribe
# City not found. Skipping...
# Processing Record 35 of Set 15 | mehamn
# Processing Record 36 of Set 15 | vestmannaeyjar
# Processing Record 37 of Set 15 | lufilufi
# Processing Record 38 of Set 15 | khorixas
# Processing Record 39 of Set 15 | manokwari
# Processing Record 40 of Set 15 | kiunga
# Processing Record 41 of Set 15 | biak
# Processing Record 42 of Set 15 | burnie
# Processing Record 43 of Set 15 | nemuro
# Processing Record 44 of Set 15 | ishigaki
# Processing Record 45 of Set 15 | tondano
# Processing Record 46 of Set 15 | pachino
# Processing Record 47 of Set 15 | marion
# Processing Record 48 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 15 | whitehorse
# Processing Record 50 of Set 15 | perehonivka
# Processing Record 1 of Set 16 | bombarral
# Processing Record 2 of Set 16 | fastiv
# Processing Record 3 of Set 16 | madimba
# Processing Record 4 of Set 16 | bambanglipuro
# Processing Record 5 of Set 16 | phirangipuram
# Processing Record 6 of Set 16 | nicoya
# Processing Record 7 of Set 16 | fougamou
# Processing Record 8 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 16 | kardla
# Processing Record 10 of Set 16 | hailar
# Processing Record 11 of Set 16 | tomatlan
# Processing Record 12 of Set 16 | chegdomyn
# Processing Record 13 of Set 16 | chumayel
# Processing Record 14 of Set 16 | phonhong
# Processing Record 15 of Set 16 | pedernales
# Processing Record 16 of Set 16 | pontal do parana
# Processing Record 17 of Set 16 | papetoai
# Processing Record 18 of Set 16 | krasnoselkup
# Processing Record 19 of Set 16 | tubruq
# City not found. Skipping...
# Processing Record 20 of Set 16 | maloy
# Processing Record 21 of Set 16 | punto fijo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %% [markdown]
# ### 1.7 Add the Data to a New DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Marsaxlokk      MT  35.8419   14.5431     81.09        78           0
# 1     Hervey Bay      AU -25.2986  152.8535     68.00        81         100
# 2      Taoudenni      ML  22.6783   -3.9836     95.88        15           2
# 3      Jamestown      US  42.0970  -79.2353     64.18        64           0
# 4         Barrow      US  71.2906 -156.7887     37.42        87          75
# 5       Maurawan      IN  26.4333   80.8833     80.64        69         100
# 6  Mar Del Plata      AR -38.0023  -57.5575     47.08        94         100
# 7        Ushuaia      AR -54.8000  -68.3000     40.66        70          20
# 8          Mogok      MM  22.9167   96.5000     68.95        92          92
# 9       Cidreira      BR -30.1811  -50.2056     65.14        79         100
#
#    Wind Speed Current Description
# 0       11.77           clear sky
# 1       10.25     overcast clouds
# 2        4.23           clear sky
# 3        5.75           clear sky
# 4       17.27                mist
# 5        5.91     overcast clouds
# 6       15.01       moderate rain
# 7        3.44          few clouds
# 8        2.37     overcast clouds
# 9       15.26     overcast clouds

# %%
# Output the DataFrame into the CSV file "WeatherPy_Database.csv"
city_data_df.to_csv(city_data_to_write, index_label="City_ID")
