# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File to Write
city_data_to_write = "Weather_Database/WeatherPy_Database.csv"

# %% [markdown]
# ### 1.3 Create 2K Random Latitudes and Longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ### 1.4 Get the Nearest City for Each Lat/Lng Pair

# %%
# Import the citipy module
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %% [markdown]
# ### 1.5 Perform an API call with the OpenWeatherMap

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Cll.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#%%script false --no-raise-error

# **** TESING ****
# Once this cell works and the data has been created,
# turn it off by uncommenting the line above to reduce
# the calls to the API.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | constitucion
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | cochrane
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | dzilam gonzalez
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | codajas
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | baghdad
# Processing Record 15 of Set 1 | acari
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | somerset east
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | havelock
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | chapleau
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | zhangjiakou
# Processing Record 25 of Set 1 | buenos aires
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | wiarton
# Processing Record 28 of Set 1 | port-gentil
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | lampang
# Processing Record 31 of Set 1 | kahului
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | kaduna
# Processing Record 34 of Set 1 | mayumba
# Processing Record 35 of Set 1 | north bend
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | taltal
# Processing Record 41 of Set 1 | petropolis
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | zhigansk
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | mundo nuevo
# Processing Record 47 of Set 1 | mareeba
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | bar harbor
# Processing Record 1 of Set 2 | nhulunbuy
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | mount isa
# Processing Record 6 of Set 2 | karpogory
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | damghan
# Processing Record 9 of Set 2 | ambilobe
# Processing Record 10 of Set 2 | choix
# Processing Record 11 of Set 2 | bandiagara
# Processing Record 12 of Set 2 | desbiens
# Processing Record 13 of Set 2 | vila do maio
# Processing Record 14 of Set 2 | nemuro
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | bonthe
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | sao jose da coroa grande
# Processing Record 19 of Set 2 | rudozem
# Processing Record 20 of Set 2 | moron
# Processing Record 21 of Set 2 | kruisfontein
# Processing Record 22 of Set 2 | south sioux city
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | husavik
# Processing Record 26 of Set 2 | rawah
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | narsaq
# Processing Record 29 of Set 2 | dunedin
# Processing Record 30 of Set 2 | zhifang
# Processing Record 31 of Set 2 | mahajanga
# Processing Record 32 of Set 2 | barwaha
# City not found. Skipping...
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | tianpeng
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | belyy yar
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | yar-sale
# Processing Record 40 of Set 2 | esik
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | orcopampa
# Processing Record 44 of Set 2 | vyazemskiy
# Processing Record 45 of Set 2 | poum
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 2 | burgos
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | caninde de sao francisco
# Processing Record 1 of Set 3 | peniche
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | north myrtle beach
# Processing Record 4 of Set 3 | saint-pierre
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | point pleasant
# Processing Record 7 of Set 3 | jeremie
# Processing Record 8 of Set 3 | takoradi
# Processing Record 9 of Set 3 | galesong
# Processing Record 10 of Set 3 | baruun-urt
# Processing Record 11 of Set 3 | naze
# Processing Record 12 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | aktau
# Processing Record 16 of Set 3 | bafq
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | cabinda
# Processing Record 19 of Set 3 | tashara
# Processing Record 20 of Set 3 | inhambane
# Processing Record 21 of Set 3 | necochea
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | puerto carreno
# Processing Record 24 of Set 3 | passo de camaragibe
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 3 | vryheid
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | mandalgovi
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | fostoria
# Processing Record 37 of Set 3 | adrar
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | kodiak
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | homer
# Processing Record 42 of Set 3 | bechem
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | matara
# Processing Record 45 of Set 3 | gumdag
# Processing Record 46 of Set 3 | sosnovo-ozerskoye
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | dali
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | hualmay
# Processing Record 2 of Set 4 | gat
# Processing Record 3 of Set 4 | belaya kholunitsa
# Processing Record 4 of Set 4 | ostrovnoy
# Processing Record 5 of Set 4 | akom
# Processing Record 6 of Set 4 | moyale
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | dolores
# Processing Record 9 of Set 4 | alta floresta
# Processing Record 10 of Set 4 | portel
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | ambon
# Processing Record 14 of Set 4 | balad
# Processing Record 15 of Set 4 | achikulak
# Processing Record 16 of Set 4 | jibuti
# Processing Record 17 of Set 4 | inirida
# Processing Record 18 of Set 4 | salym
# Processing Record 19 of Set 4 | senador jose porfirio
# Processing Record 20 of Set 4 | muros
# Processing Record 21 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 4 | batemans bay
# Processing Record 23 of Set 4 | guanajuato
# Processing Record 24 of Set 4 | tuktoyaktuk
# Processing Record 25 of Set 4 | umm lajj
# Processing Record 26 of Set 4 | saint-georges
# Processing Record 27 of Set 4 | pingliang
# Processing Record 28 of Set 4 | upernavik
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | haines junction
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | hofn
# Processing Record 33 of Set 4 | fredericton
# Processing Record 34 of Set 4 | manta
# Processing Record 35 of Set 4 | agirish
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | tuatapere
# Processing Record 38 of Set 4 | elat
# Processing Record 39 of Set 4 | brae
# Processing Record 40 of Set 4 | gayny
# Processing Record 41 of Set 4 | san patricio
# Processing Record 42 of Set 4 | te anau
# Processing Record 43 of Set 4 | cabadiangan
# Processing Record 44 of Set 4 | flin flon
# Processing Record 45 of Set 4 | sri aman
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | maymyo
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | udachnyy
# Processing Record 50 of Set 4 | ternate
# Processing Record 1 of Set 5 | tunduma
# Processing Record 2 of Set 5 | parrita
# Processing Record 3 of Set 5 | kommunar
# Processing Record 4 of Set 5 | atasu
# Processing Record 5 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 5 | saskylakh
# Processing Record 7 of Set 5 | axim
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 10 of Set 5 | colquiri
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | kathmandu
# Processing Record 13 of Set 5 | zabid
# Processing Record 14 of Set 5 | sitio novo do tocantins
# Processing Record 15 of Set 5 | aykhal
# Processing Record 16 of Set 5 | galich
# Processing Record 17 of Set 5 | manaure
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 5 | galveston
# Processing Record 22 of Set 5 | bonavista
# Processing Record 23 of Set 5 | formosa
# Processing Record 24 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 5 | akyab
# Processing Record 26 of Set 5 | aban
# Processing Record 27 of Set 5 | tautira
# Processing Record 28 of Set 5 | pacific grove
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | bodden town
# Processing Record 33 of Set 5 | dauphin
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | jiwani
# Processing Record 36 of Set 5 | sorland
# Processing Record 37 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | lake cowichan
# Processing Record 40 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | potosi
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | winona
# Processing Record 45 of Set 5 | filadelfia
# Processing Record 46 of Set 5 | cayenne
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | hovd
# Processing Record 50 of Set 5 | prabumulih
# Processing Record 1 of Set 6 | meadow lake
# Processing Record 2 of Set 6 | kampot
# Processing Record 3 of Set 6 | comodoro rivadavia
# Processing Record 4 of Set 6 | mocuba
# Processing Record 5 of Set 6 | nantucket
# Processing Record 6 of Set 6 | taldan
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | vodnyy
# Processing Record 9 of Set 6 | aqtobe
# Processing Record 10 of Set 6 | kysyl-syr
# Processing Record 11 of Set 6 | yerkoy
# Processing Record 12 of Set 6 | liling
# Processing Record 13 of Set 6 | ribeira grande
# Processing Record 14 of Set 6 | moussoro
# Processing Record 15 of Set 6 | carauari
# Processing Record 16 of Set 6 | alihe
# Processing Record 17 of Set 6 | balakhninskiy
# Processing Record 18 of Set 6 | bhandaria
# Processing Record 19 of Set 6 | faya
# Processing Record 20 of Set 6 | bulgan
# Processing Record 21 of Set 6 | fare
# Processing Record 22 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 6 | elk plain
# Processing Record 24 of Set 6 | ugoofaaru
# Processing Record 25 of Set 6 | balkanabat
# Processing Record 26 of Set 6 | alekseyevsk
# Processing Record 27 of Set 6 | port lincoln
# Processing Record 28 of Set 6 | shieli
# Processing Record 29 of Set 6 | cherskiy
# Processing Record 30 of Set 6 | mana
# Processing Record 31 of Set 6 | sonoita
# Processing Record 32 of Set 6 | saint-augustin
# Processing Record 33 of Set 6 | dingle
# Processing Record 34 of Set 6 | khandbari
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 6 | panzhihua
# Processing Record 37 of Set 6 | igarka
# Processing Record 38 of Set 6 | cidreira
# Processing Record 39 of Set 6 | abu dhabi
# Processing Record 40 of Set 6 | merauke
# Processing Record 41 of Set 6 | songea
# Processing Record 42 of Set 6 | karratha
# Processing Record 43 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 6 | chuy
# Processing Record 45 of Set 6 | nome
# Processing Record 46 of Set 6 | shenjiamen
# Processing Record 47 of Set 6 | lasa
# Processing Record 48 of Set 6 | san andres
# Processing Record 49 of Set 6 | pipili
# Processing Record 50 of Set 6 | saldanha
# Processing Record 1 of Set 7 | rathenow
# Processing Record 2 of Set 7 | san juan
# Processing Record 3 of Set 7 | iranshahr
# Processing Record 4 of Set 7 | khatanga
# Processing Record 5 of Set 7 | pocone
# Processing Record 6 of Set 7 | la ronge
# Processing Record 7 of Set 7 | ixtapa
# Processing Record 8 of Set 7 | puerto ayacucho
# Processing Record 9 of Set 7 | verkhnevilyuysk
# Processing Record 10 of Set 7 | port said
# Processing Record 11 of Set 7 | duz
# City not found. Skipping...
# Processing Record 12 of Set 7 | torbay
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | seddon
# Processing Record 16 of Set 7 | ahuimanu
# Processing Record 17 of Set 7 | leningradskiy
# Processing Record 18 of Set 7 | vrangel
# Processing Record 19 of Set 7 | usinsk
# Processing Record 20 of Set 7 | ayagoz
# Processing Record 21 of Set 7 | russell
# Processing Record 22 of Set 7 | shihezi
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | esso
# Processing Record 25 of Set 7 | karimganj
# Processing Record 26 of Set 7 | espanola
# Processing Record 27 of Set 7 | tulun
# Processing Record 28 of Set 7 | vestmanna
# Processing Record 29 of Set 7 | caledon
# Processing Record 30 of Set 7 | digby
# Processing Record 31 of Set 7 | caetite
# Processing Record 32 of Set 7 | yamada
# Processing Record 33 of Set 7 | port hardy
# Processing Record 34 of Set 7 | kaitangata
# Processing Record 35 of Set 7 | oistins
# Processing Record 36 of Set 7 | atar
# Processing Record 37 of Set 7 | rovaniemi
# Processing Record 38 of Set 7 | shostka
# Processing Record 39 of Set 7 | wiltz
# Processing Record 40 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 7 | srednekolymsk
# Processing Record 42 of Set 7 | lompoc
# Processing Record 43 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 7 | phalaborwa
# Processing Record 45 of Set 7 | afanasyevo
# City not found. Skipping...
# Processing Record 46 of Set 7 | santander
# Processing Record 47 of Set 7 | kwidzyn
# Processing Record 48 of Set 7 | jimo
# Processing Record 49 of Set 7 | pusad
# Processing Record 50 of Set 7 | saint-philippe
# Processing Record 1 of Set 8 | sibolga
# Processing Record 2 of Set 8 | sibut
# Processing Record 3 of Set 8 | tinos
# Processing Record 4 of Set 8 | aswan
# Processing Record 5 of Set 8 | la romana
# Processing Record 6 of Set 8 | esperance
# Processing Record 7 of Set 8 | badaojiang
# City not found. Skipping...
# Processing Record 8 of Set 8 | ilulissat
# Processing Record 9 of Set 8 | narrabri
# Processing Record 10 of Set 8 | maldonado
# Processing Record 11 of Set 8 | leh
# Processing Record 12 of Set 8 | aksu
# Processing Record 13 of Set 8 | nouadhibou
# Processing Record 14 of Set 8 | chateauroux
# Processing Record 15 of Set 8 | lillooet
# Processing Record 16 of Set 8 | sinnamary
# Processing Record 17 of Set 8 | calvinia
# Processing Record 18 of Set 8 | mindif
# Processing Record 19 of Set 8 | monrovia
# Processing Record 20 of Set 8 | tocopilla
# Processing Record 21 of Set 8 | kieta
# Processing Record 22 of Set 8 | shevchenkove
# Processing Record 23 of Set 8 | carlsbad
# Processing Record 24 of Set 8 | charters towers
# Processing Record 25 of Set 8 | miles city
# Processing Record 26 of Set 8 | konevo
# Processing Record 27 of Set 8 | dorado
# Processing Record 28 of Set 8 | sanmenxia
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | nichinan
# Processing Record 31 of Set 8 | manono
# Processing Record 32 of Set 8 | tequila
# Processing Record 33 of Set 8 | huntington
# Processing Record 34 of Set 8 | broken hill
# Processing Record 35 of Set 8 | benoy
# Processing Record 36 of Set 8 | balabag
# Processing Record 37 of Set 8 | saurimo
# Processing Record 38 of Set 8 | nago
# Processing Record 39 of Set 8 | tateyama
# Processing Record 40 of Set 8 | tarragona
# Processing Record 41 of Set 8 | santa cruz
# Processing Record 42 of Set 8 | yerbogachen
# Processing Record 43 of Set 8 | half moon bay
# Processing Record 44 of Set 8 | kavieng
# Processing Record 45 of Set 8 | miyako
# Processing Record 46 of Set 8 | catamarca
# Processing Record 47 of Set 8 | trincomalee
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | bongandanga
# Processing Record 50 of Set 8 | bilma
# Processing Record 1 of Set 9 | honiara
# Processing Record 2 of Set 9 | tura
# Processing Record 3 of Set 9 | kutum
# Processing Record 4 of Set 9 | nagato
# Processing Record 5 of Set 9 | miracema do tocantins
# Processing Record 6 of Set 9 | shache
# Processing Record 7 of Set 9 | raudeberg
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | chifeng
# Processing Record 10 of Set 9 | kenai
# Processing Record 11 of Set 9 | hay river
# Processing Record 12 of Set 9 | haverfordwest
# Processing Record 13 of Set 9 | oksfjord
# Processing Record 14 of Set 9 | sambava
# Processing Record 15 of Set 9 | wanning
# Processing Record 16 of Set 9 | mao
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | lazaro cardenas
# Processing Record 19 of Set 9 | kamaishi
# Processing Record 20 of Set 9 | moree
# Processing Record 21 of Set 9 | ghatanji
# Processing Record 22 of Set 9 | marawi
# Processing Record 23 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 9 | biograd na moru
# Processing Record 25 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 9 | crailsheim
# Processing Record 27 of Set 9 | korla
# Processing Record 28 of Set 9 | port augusta
# Processing Record 29 of Set 9 | el alto
# Processing Record 30 of Set 9 | batagay
# Processing Record 31 of Set 9 | cam ranh
# Processing Record 32 of Set 9 | swan river
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | coahuayana
# Processing Record 35 of Set 9 | mugur-aksy
# Processing Record 36 of Set 9 | feijo
# Processing Record 37 of Set 9 | hirara
# Processing Record 38 of Set 9 | umm kaddadah
# Processing Record 39 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 9 | souillac
# Processing Record 41 of Set 9 | santa maria
# Processing Record 42 of Set 9 | mehamn
# Processing Record 43 of Set 9 | fairbanks
# Processing Record 44 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 9 | tabuk
# Processing Record 46 of Set 9 | yabrud
# Processing Record 47 of Set 9 | vagur
# Processing Record 48 of Set 9 | cedar mill
# Processing Record 49 of Set 9 | saint-paul
# Processing Record 50 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 10 | teya
# Processing Record 2 of Set 10 | plettenberg bay
# Processing Record 3 of Set 10 | borodino
# Processing Record 4 of Set 10 | lulea
# Processing Record 5 of Set 10 | weyburn
# Processing Record 6 of Set 10 | taperoa
# Processing Record 7 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 10 | ahipara
# Processing Record 9 of Set 10 | longyearbyen
# Processing Record 10 of Set 10 | onda
# Processing Record 11 of Set 10 | kavaratti
# Processing Record 12 of Set 10 | caravelas
# Processing Record 13 of Set 10 | banapur
# Processing Record 14 of Set 10 | san angelo
# Processing Record 15 of Set 10 | puerto escondido
# Processing Record 16 of Set 10 | saint-francois
# Processing Record 17 of Set 10 | port blair
# Processing Record 18 of Set 10 | beira
# Processing Record 19 of Set 10 | berlevag
# Processing Record 20 of Set 10 | shasta lake
# Processing Record 21 of Set 10 | ofaqim
# Processing Record 22 of Set 10 | bartlesville
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | riohacha
# Processing Record 25 of Set 10 | tual
# Processing Record 26 of Set 10 | buala
# Processing Record 27 of Set 10 | kangaatsiaq
# Processing Record 28 of Set 10 | bakchar
# Processing Record 29 of Set 10 | glenwood springs
# Processing Record 30 of Set 10 | shuangyang
# Processing Record 31 of Set 10 | qaqortoq
# Processing Record 32 of Set 10 | svetlyy
# Processing Record 33 of Set 10 | seymchan
# Processing Record 34 of Set 10 | hailun
# Processing Record 35 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 10 | guerrero
# Processing Record 37 of Set 10 | ilhabela
# Processing Record 38 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 39 of Set 10 | acarau
# Processing Record 40 of Set 10 | kropotkin
# Processing Record 41 of Set 10 | besuki
# Processing Record 42 of Set 10 | urgut
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | vaitape
# Processing Record 45 of Set 10 | paka
# Processing Record 46 of Set 10 | arlit
# Processing Record 47 of Set 10 | tacna
# Processing Record 48 of Set 10 | bontang
# Processing Record 49 of Set 10 | walvis bay
# Processing Record 50 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 11 | manokwari
# Processing Record 2 of Set 11 | coolum beach
# Processing Record 3 of Set 11 | hanzhong
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | avera
# Processing Record 6 of Set 11 | khash
# Processing Record 7 of Set 11 | heze
# Processing Record 8 of Set 11 | rudnogorsk
# Processing Record 9 of Set 11 | tacuati
# Processing Record 10 of Set 11 | paramonga
# Processing Record 11 of Set 11 | dauriya
# Processing Record 12 of Set 11 | tunceli
# Processing Record 13 of Set 11 | inverell
# Processing Record 14 of Set 11 | cockburn town
# Processing Record 15 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 11 | bastia
# Processing Record 17 of Set 11 | kalianget
# Processing Record 18 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 11 | road town
# Processing Record 20 of Set 11 | southbridge
# Processing Record 21 of Set 11 | mackay
# Processing Record 22 of Set 11 | vestmannaeyjar
# Processing Record 23 of Set 11 | nelspruit
# Processing Record 24 of Set 11 | sisimiut
# Processing Record 25 of Set 11 | arman
# Processing Record 26 of Set 11 | yei
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | talnakh
# Processing Record 29 of Set 11 | maun
# Processing Record 30 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 31 of Set 11 | burnie
# Processing Record 32 of Set 11 | morondava
# Processing Record 33 of Set 11 | sault sainte marie
# Processing Record 34 of Set 11 | lata
# Processing Record 35 of Set 11 | kapit
# Processing Record 36 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 11 | camacupa
# Processing Record 38 of Set 11 | pathein
# Processing Record 39 of Set 11 | monster
# Processing Record 40 of Set 11 | kilindoni
# Processing Record 41 of Set 11 | bahia blanca
# Processing Record 42 of Set 11 | oromocto
# Processing Record 43 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 11 | los patios
# Processing Record 45 of Set 11 | saint george
# Processing Record 46 of Set 11 | iquitos
# Processing Record 47 of Set 11 | palladam
# Processing Record 48 of Set 11 | derzhavinsk
# Processing Record 49 of Set 11 | eureka
# Processing Record 50 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 1 of Set 12 | rojhan
# Processing Record 2 of Set 12 | halifax
# Processing Record 3 of Set 12 | zonguldak
# Processing Record 4 of Set 12 | billings
# Processing Record 5 of Set 12 | bandarbeyla
# Processing Record 6 of Set 12 | vanimo
# Processing Record 7 of Set 12 | orangeburg
# Processing Record 8 of Set 12 | korem
# Processing Record 9 of Set 12 | ningan
# City not found. Skipping...
# Processing Record 10 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 12 | xinzhi
# Processing Record 12 of Set 12 | geraldton
# Processing Record 13 of Set 12 | paamiut
# Processing Record 14 of Set 12 | fuerte olimpo
# Processing Record 15 of Set 12 | alyangula
# Processing Record 16 of Set 12 | havre-saint-pierre
# Processing Record 17 of Set 12 | sao domingos
# Processing Record 18 of Set 12 | zhangye
# Processing Record 19 of Set 12 | almaznyy
# Processing Record 20 of Set 12 | tezu
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | baykit
# Processing Record 23 of Set 12 | kaeo
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | clyde
# Processing Record 27 of Set 12 | bure
# Processing Record 28 of Set 12 | alizai
# Processing Record 29 of Set 12 | pamanukan
# Processing Record 30 of Set 12 | moratuwa
# Processing Record 31 of Set 12 | abu samrah
# Processing Record 32 of Set 12 | camopi
# Processing Record 33 of Set 12 | qasigiannguit
# Processing Record 34 of Set 12 | raca
# Processing Record 35 of Set 12 | nongstoin
# Processing Record 36 of Set 12 | sarkand
# Processing Record 37 of Set 12 | ketchikan
# Processing Record 38 of Set 12 | salinopolis
# Processing Record 39 of Set 12 | tumut
# Processing Record 40 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 12 | sovetskiy
# Processing Record 42 of Set 12 | olga
# Processing Record 43 of Set 12 | kokoda
# Processing Record 44 of Set 12 | khandyga
# Processing Record 45 of Set 12 | clearwater
# Processing Record 46 of Set 12 | nuuk
# Processing Record 47 of Set 12 | chapais
# Processing Record 48 of Set 12 | nalut
# Processing Record 49 of Set 12 | bibiani
# Processing Record 50 of Set 12 | nabire
# Processing Record 1 of Set 13 | nanae
# Processing Record 2 of Set 13 | nurota
# Processing Record 3 of Set 13 | biak
# Processing Record 4 of Set 13 | batagay-alyta
# Processing Record 5 of Set 13 | portland
# Processing Record 6 of Set 13 | kerouane
# Processing Record 7 of Set 13 | isabela
# Processing Record 8 of Set 13 | nikolayevsk-na-amure
# Processing Record 9 of Set 13 | krasnoborsk
# Processing Record 10 of Set 13 | petatlan
# Processing Record 11 of Set 13 | vila velha
# Processing Record 12 of Set 13 | matagami
# Processing Record 13 of Set 13 | bay roberts
# Processing Record 14 of Set 13 | sayyan
# Processing Record 15 of Set 13 | barbastro
# Processing Record 16 of Set 13 | san francisco
# Processing Record 17 of Set 13 | henties bay
# Processing Record 18 of Set 13 | margate
# Processing Record 19 of Set 13 | sao joao da barra
# Processing Record 20 of Set 13 | bathsheba
# Processing Record 21 of Set 13 | ruteng
# Processing Record 22 of Set 13 | palauig
# Processing Record 23 of Set 13 | palmer
# Processing Record 24 of Set 13 | marzuq
# Processing Record 25 of Set 13 | birin
# Processing Record 26 of Set 13 | mumford
# Processing Record 27 of Set 13 | ayan
# Processing Record 28 of Set 13 | kollo
# Processing Record 29 of Set 13 | creston
# Processing Record 30 of Set 13 | sao miguel do araguaia
# Processing Record 31 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 13 | namatanai
# Processing Record 33 of Set 13 | lamu
# Processing Record 34 of Set 13 | alofi
# Processing Record 35 of Set 13 | lisakovsk
# Processing Record 36 of Set 13 | high level
# Processing Record 37 of Set 13 | kabare
# Processing Record 38 of Set 13 | klaksvik
# Processing Record 39 of Set 13 | jardim
# Processing Record 40 of Set 13 | mogadishu
# Processing Record 41 of Set 13 | mezen
# Processing Record 42 of Set 13 | muroto
# Processing Record 43 of Set 13 | tilichiki
# Processing Record 44 of Set 13 | diamantina
# Processing Record 45 of Set 13 | santa pola
# Processing Record 46 of Set 13 | mason city
# Processing Record 47 of Set 13 | nanning
# Processing Record 48 of Set 13 | mazagao
# Processing Record 49 of Set 13 | kamenka
# Processing Record 50 of Set 13 | spornoye
# Processing Record 1 of Set 14 | auki
# Processing Record 2 of Set 14 | monticello
# Processing Record 3 of Set 14 | lakatoro
# Processing Record 4 of Set 14 | florida
# Processing Record 5 of Set 14 | abbeville
# Processing Record 6 of Set 14 | toledo
# Processing Record 7 of Set 14 | kokkarion
# Processing Record 8 of Set 14 | gamba
# Processing Record 9 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 14 | kaabong
# Processing Record 11 of Set 14 | papara
# Processing Record 12 of Set 14 | evensk
# Processing Record 13 of Set 14 | badlapur
# Processing Record 14 of Set 14 | jumla
# Processing Record 15 of Set 14 | clyde river
# Processing Record 16 of Set 14 | mayor pablo lagerenza
# Processing Record 17 of Set 14 | paita
# Processing Record 18 of Set 14 | kudahuvadhoo
# Processing Record 19 of Set 14 | myitkyina
# Processing Record 20 of Set 14 | valparaiso
# Processing Record 21 of Set 14 | pyaozerskiy
# Processing Record 22 of Set 14 | berdigestyakh
# Processing Record 23 of Set 14 | novoagansk
# Processing Record 24 of Set 14 | bria
# Processing Record 25 of Set 14 | galle
# Processing Record 26 of Set 14 | zverinogolovskoye
# Processing Record 27 of Set 14 | lufilufi
# Processing Record 28 of Set 14 | chimoio
# Processing Record 29 of Set 14 | jieshi
# Processing Record 30 of Set 14 | sudbury
# Processing Record 31 of Set 14 | coruripe
# Processing Record 32 of Set 14 | hauterive
# Processing Record 33 of Set 14 | strangnas
# Processing Record 34 of Set 14 | mossoro
# Processing Record 35 of Set 14 | calobre
# City not found. Skipping...
# Processing Record 36 of Set 14 | do rud
# City not found. Skipping...
# Processing Record 37 of Set 14 | belmonte
# Processing Record 38 of Set 14 | yeniseysk
# Processing Record 39 of Set 14 | xining
# Processing Record 40 of Set 14 | guerrero negro
# Processing Record 41 of Set 14 | aksarka
# Processing Record 42 of Set 14 | lakes entrance
# Processing Record 43 of Set 14 | jackson
# Processing Record 44 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 14 | pushkinskiye gory
# Processing Record 46 of Set 14 | kidal
# Processing Record 47 of Set 14 | santa ana
# Processing Record 48 of Set 14 | samarinda
# Processing Record 49 of Set 14 | khorramshahr
# Processing Record 50 of Set 14 | bud
# Processing Record 1 of Set 15 | shahr-e babak
# Processing Record 2 of Set 15 | solnechnyy
# Processing Record 3 of Set 15 | sendai
# Processing Record 4 of Set 15 | copiapo
# Processing Record 5 of Set 15 | asau
# Processing Record 6 of Set 15 | taitung
# Processing Record 7 of Set 15 | charyshskoye
# Processing Record 8 of Set 15 | waddan
# Processing Record 9 of Set 15 | devgarh
# Processing Record 10 of Set 15 | taoudenni
# Processing Record 11 of Set 15 | taos
# Processing Record 12 of Set 15 | gopalpur
# Processing Record 13 of Set 15 | puerto del rosario
# Processing Record 14 of Set 15 | inta
# Processing Record 15 of Set 15 | kununurra
# Processing Record 16 of Set 15 | pangody
# Processing Record 17 of Set 15 | roebourne
# Processing Record 18 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 15 | ossora
# Processing Record 20 of Set 15 | marystown
# Processing Record 21 of Set 15 | saint anthony
# Processing Record 22 of Set 15 | ambanja
# Processing Record 23 of Set 15 | san luis
# Processing Record 24 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 15 | acandi
# Processing Record 26 of Set 15 | aquiraz
# Processing Record 27 of Set 15 | bela
# Processing Record 28 of Set 15 | labytnangi
# Processing Record 29 of Set 15 | kawambwa
# Processing Record 30 of Set 15 | wajima
# Processing Record 31 of Set 15 | vila franca do campo
# Processing Record 32 of Set 15 | rawlins
# Processing Record 33 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 34 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 15 | cartagena del chaira
# Processing Record 36 of Set 15 | puerto plata
# Processing Record 37 of Set 15 | lima
# Processing Record 38 of Set 15 | ulladulla
# Processing Record 39 of Set 15 | dubbo
# Processing Record 40 of Set 15 | koksovyy
# Processing Record 41 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 42 of Set 15 | neverkino
# Processing Record 43 of Set 15 | waipawa
# Processing Record 44 of Set 15 | vorukh
# Processing Record 45 of Set 15 | kirksville
# Processing Record 46 of Set 15 | codrington
# Processing Record 47 of Set 15 | bhayavadar
# Processing Record 48 of Set 15 | olafsvik
# Processing Record 49 of Set 15 | bakel
# Processing Record 50 of Set 15 | batangafo
# Processing Record 1 of Set 16 | puteyets
# Processing Record 2 of Set 16 | lixourion
# Processing Record 3 of Set 16 | yulara
# Processing Record 4 of Set 16 | solano
# Processing Record 5 of Set 16 | kalengwa
# Processing Record 6 of Set 16 | nishihara
# Processing Record 7 of Set 16 | voh
# Processing Record 8 of Set 16 | marsa matruh
# Processing Record 9 of Set 16 | dingli
# Processing Record 10 of Set 16 | yeppoon
# Processing Record 11 of Set 16 | presque isle
# Processing Record 12 of Set 16 | shebekino
# Processing Record 13 of Set 16 | karpathos
# Processing Record 14 of Set 16 | paris
# Processing Record 15 of Set 16 | stornoway
# Processing Record 16 of Set 16 | san jose
# Processing Record 17 of Set 16 | la paz
# Processing Record 18 of Set 16 | yaring
# Processing Record 19 of Set 16 | tarko-sale
# Processing Record 20 of Set 16 | ballesteros
# Processing Record 21 of Set 16 | santa elena
# Processing Record 22 of Set 16 | thinadhoo
# Processing Record 23 of Set 16 | mwene-ditu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %% [markdown]
# ### 1.7 Add the Data to a New DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Fortuna      US  40.5982 -124.1573     63.99        93          94
# 1           Atuona      PF  -9.8000 -139.0333     76.87        82          37
# 2     Constitucion      CL -35.3333  -72.4167     47.70        85         100
# 3          Qaanaaq      GL  77.4840  -69.3632     36.64        79          80
# 4           Albany      US  42.6001  -73.9662     70.57        79          99
# 5          Rikitea      PF -23.1203 -134.9692     72.28        75           0
# 6         Cochrane      CA  51.1834 -114.4687     81.64        25           0
# 7       Chokurdakh      RU  70.6333  147.9167     50.67        61         100
# 8  Dzilam Gonzalez      MX  21.2833  -88.9333     90.05        59          21
# 9           Hobart      AU -42.8794  147.3294     47.26        91         100
#
#    Wind Speed Current Description
# 0        5.88     overcast clouds
# 1       27.69          light rain
# 2        6.06     overcast clouds
# 3        2.04       broken clouds
# 4        1.77     overcast clouds
# 5       22.39          light rain
# 6       17.27           clear sky
# 7        7.67     overcast clouds
# 8        6.58          few clouds
# 9        1.14     overcast clouds

# %%
# Output the DataFrame into the CSV file "WeatherPy_Database.csv"
city_data_df.to_csv(city_data_to_write, index_label="City_ID")
